# %% [markdown]
# # Neural network lab
#
# ## Forward propagation, regression

# %%
import numpy as np
import scipy 
import matplotlib.pyplot as plt
from scipy.special import softmax
sigmoid = scipy.special.expit
def identity(x): return x
def relu(x): return np.maximum(0, x)

# Generate some data
X = np.arange(-3, 3, .01).reshape(-1, 1)
y = np.sin(2 * X) + 0.5 * np.cos(3.5 * X)

# Create numpy array
dataset = np.column_stack((X, y))

# %%
# Plot original data

plt.plot(X, y, -3, 3)
plt.ylim(-1.5, 1.5)
plt.show()

# %%
# Define a function to make a nice plot as well as take a model function
def make_plot(model=None):

    plt.plot(X, y, -3, 3)

    # Define a function that takes x1 and x2
    if model != None:
        yhat = model(X)

        plt.plot(X, yhat, -3, 3)

    plt.ylim(-1.5, 1.5)
    plt.show()
    
make_plot()

# %%
# Single layer network for classification: 1 input to 1 output

def run_model(x):
    pass

make_plot(run_model)

# %%
# 2 layer network for regression: 1 -> 2 -> 1

def run_model(x):
    pass

make_plot(run_model)

# %%
# 2 layer network for regression: 1 -> 4 -> 1

def run_model(x):
    pass

make_plot(run_model)

# %%
# 3 layer network for regression: 1 -> 4 -> 4 -> 1
"""
np.array([[ 0.12155865,  0.10815335, -1.20835042,  0.52835267]])
np.array([[-0.0235204 , -0.19152331, -0.14089048, -0.25272617],
       [ 0.32699534, -0.38013902,  0.54243556,  0.25683042],
       [-0.04621448,  0.00813845,  1.69040037,  1.4110488 ],
       [ 0.63283364,  0.24849245,  2.53721742,  2.06998637]])
np.array([[ 0.02431233],
       [-0.16956916],
       [-2.02027782],
       [ 1.9463195 ]])
np.array([-0.00806077,  0.22653225, -1.26134773,  0.41625975])
np.array([-0.4227883 , -0.02204849, -1.63811377, -0.03288794])
np.array([-1.38112186])
"""


def run_model(x):
    pass

make_plot(run_model)

# %%
# 3 layer network for regression: 1 -> 10 -> 10 -> 1
"""
np.array([[-0.3866335 ,  1.22773007,  0.67847179,  0.65501822, -0.15316389,
         0.49345114, -0.02089015, -0.87852615,  0.19825285, -0.3315195 ]])
np.array([[ 0.37601402,  0.19852309, -0.22466922,  0.13024717, -0.05970552,
        -0.78292536, -0.11650132,  1.07339813, -0.07847237,  0.55474854],
       [-0.02806266, -0.07036703, -0.06804836, -0.96934427,  0.81204708,
         0.88679487, -0.7112336 ,  0.36050283, -0.01760473, -0.01097377],
       [-0.90521773, -0.81761366, -0.24057353,  0.73435294, -0.41180007,
        -0.28069956, -0.53558707, -0.21617463, -0.76675233, -0.74182478],
       [ 0.24891995, -0.67871944, -0.22488956,  0.83285295,  0.21198337,
         0.10887862,  0.09602208,  0.02248349, -0.87688969, -0.2969216 ],
       [-0.5937938 ,  0.61103019,  0.36097644,  0.43957694, -0.00229664,
         0.45621743, -0.12933473,  0.49095399,  0.39523232, -0.27583114],
       [ 0.48467229,  0.10693162, -0.15866904, -0.34964593, -0.13767152,
         0.28165872, -0.23869839,  0.54198538,  0.14707785,  0.17347148],
       [ 0.5759661 ,  0.17105464, -0.02502986, -0.43166531,  0.25652219,
        -0.11878174, -0.12886888,  0.3665429 , -0.42890808,  0.00884967],
       [-0.13503918,  0.20543123, -0.21909093,  0.87242845, -0.15248716,
        -0.44964063, -0.25697451, -0.54208114,  0.22430706,  0.02933169],
       [-0.36877049,  0.3204309 , -0.18765043,  0.12751145, -0.73523329,
        -0.58944732,  0.29330638, -0.47433356,  0.09663926, -0.17931732],
       [-0.4417936 ,  0.31193614,  0.24926272,  0.61974113, -0.39831436,
        -0.23644935,  0.51859901,  0.13315893,  0.20060326,  0.08812687]])
np.array([[-0.21757166],
       [ 0.91730965],
       [-0.12834902],
       [-1.72555008],
       [ 0.25057543],
       [-0.98376135],
       [ 0.61567297],
       [ 0.82502797],
       [ 1.1057196 ],
       [ 0.50591329]])
np.array([ 0.89388068,  0.8258213 ,  1.30956666,  1.13211787,  0.05877322,
        0.39368489, -0.06566222, -0.07988379, -0.06490795,  0.04351646])
np.array([-0.0011819 ,  0.1861154 ,  0.        , -0.65144625,  0.14470171,
       -0.33178158,  0.        ,  0.04867345,  0.49718796,  0.11247931])
np.array([0.25303498])
"""

def run_model(x):
    pass

make_plot(run_model)
