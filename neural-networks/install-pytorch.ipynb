# %%
# Run this cell to check if PyTorch is available and install if it's not.

import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

try:
    import torch
except ImportError:
    # %pip install torch torchvision
    import torch

from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Determine if we can use a GPU

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# Run this cell if you have an old version of pytorch and you want to upgrade to the newest version (2.10)

# %pip install --force-reinstall torch torchvision
