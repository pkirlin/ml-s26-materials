# %%
# Generate data specifically cubic data, y= x^{3}- 3x + 2

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x_data = np.arange(-3, 3, .1)
y_numeric = x_data ** 3 - 3 * x_data + 2

# %%
# Plot original data

plt.plot(x_data, y_numeric, -3, 3)
plt.show()

# %% [markdown]
# # Neural Network 1: Regression, no hidden layer

# %%
# Neural network 1, no hidden layer, regression (should duplicate linear regression)

# Activation function is identity function (not sigmoid)
# Loss function is squared error

X_train = np.array(x_data).reshape((-1, 1))
y_train = y_numeric

W = np.array([[.1]])
b = np.array([[.2]])

def compute_loss(a, y):
    return .5 * (a - y) ** 2

def compute_cost(X_data, y_data):
    m = X_data.shape[0] # number of data points
    cost = 0
    
    for i in range(m):
        y_hat = run_model(X_data[i])
        y = y_data[i]
        cost += compute_loss(y_hat, y)
    total_cost = (1 / (2 * m)) * cost

    return total_cost

def run_model(x):
    return x @ W + b

def loss_deriv(a, y):
    return a-y

def backward_prop(x, y):

    z1 = x @ W + b
    a1 = z1
    
    # your code here

# %%
run_model(X_train[0])

# %%
compute_cost(X_train, y_train)

# %%
backward_prop(X_train[0], y_train[0])

# %%
# gradient descent:

W = np.array([[-.1]])
b = np.array([[.2]])
ALPHA = .01

J_sequence = []

for ctr in range(0, 6000):
    total_dL_dw = 0
    total_dL_db = 0
    for i in range(X_train.shape[0]):   # m
        dL_dw, dL_db = backward_prop(X_train[i], y_train[i])
        total_dL_dw += dL_dw
        total_dL_db += dL_db  
    W -= ALPHA * total_dL_dw/X_train.shape[0]
    b -= ALPHA * total_dL_db/X_train.shape[0]
                              
    J_sequence.append(compute_cost(X_train, y_train))
    
print("Final W:", W, b)
print("Final cost:", compute_cost(X_train, y_train))

# %%
# Let's plot the cost as a function of number of iterations of the
# gradient descent algorithm.

plt.scatter(range(0, len(J_sequence)), J_sequence)
plt.show()

# %%
# Recreate original plot

y_predicted = run_model(X_train)
plt.plot(x_data, y_numeric, -3, 3)
plt.plot(x_data, y_predicted)
plt.show()

# %%
# Verify this matches linear regression

# Download and install scikit-learn if not already done:
# %pip install scikit-learn

# Import the logistic regression functionality from scikit-learn
from sklearn.linear_model import LinearRegression

# Create a logistic regression model and train it on our training data:
model = LinearRegression(fit_intercept=True).fit(X_train, y_train)

# model.coef_ contains the w vector that this linear regression model was able to find

print("w found through scikit-learn:", model.coef_, model.intercept_)

# %% [markdown]
# # Neural Network 2, 1 hidden layer, regression

# %%
# Neural network 2, 1 hidden layer, regression

# Activation function is identity function (not sigmoid)
# Loss function is squared error

X_train = np.array(x_data).reshape((-1, 1))
y_train = y_numeric.reshape((-1, 1))

W1 = np.random.rand(1, 3)
W2 = np.random.rand(3, 1)
b1 = np.random.rand(1, 3)
b2 = np.random.rand(1, 1)

def relu(z):
    return np.maximum(0, z)

def relu_deriv(z):
    return (z >= 0).astype(int)  

def compute_loss(a, y):
    return .5 * (a - y) ** 2

def compute_cost(X_data, y_data):
    m = X_data.shape[0] # number of data points
    cost = 0
    
    for i in range(m):
        y_hat = run_model(X_data[i])
        y = y_data[i]
        cost += compute_loss(y_hat, y)
    total_cost = (1 / (2 * m)) * cost

    return total_cost

def run_model(x):
    z1 = x @ W1 + b1
    a1 = relu(z1)
    z2 = a1 @ W2 + b2
    a2 = z2
    return a2

def loss_deriv(a, y):
    return a-y

def backward_prop(x, y):
    z1 = x @ W1 + b1
    a1 = relu(z1)
    z2 = a1 @ W2 + b2
    a2 = z2

    # your code here

# %%
run_model(X_train[0])

# %%
compute_cost(X_train, y_train)

# %%
backward_prop(X_train[0], y_train[0])

# %%
# gradient descent:

W1 = np.random.rand(1, 10)
W2 = np.random.rand(10, 1)
b1 = np.random.rand(1, 10)
b2 = np.random.rand(1, 1)
ALPHA = .01

J_sequence = []

for ctr in range(0, 3000):
    
    grad_W1 = np.zeros(W1.shape)
    grad_W2 = np.zeros(W2.shape)
    grad_b1 = np.zeros(b1.shape)
    grad_b2 = np.zeros(b2.shape)
    
    for i in range(X_train.shape[0]):   # m
        gW1, gb1, gW2, gb2 = backward_prop(X_train[i], y_train[i])
        grad_W1 += gW1
        grad_b1 += gb1
        grad_W2 += gW2
        grad_b2 += gb2
        
    W1 -= ALPHA * grad_W1/X_train.shape[0]
    b1 -= ALPHA * grad_b1/X_train.shape[0]
    W2 -= ALPHA * grad_W2/X_train.shape[0]
    b2 -= ALPHA * grad_b2/X_train.shape[0]
                              
    J_sequence.append(compute_cost(X_train, y_train))
    
print("Final W:", W1, b1, W2, b2)
print("Final cost:", compute_cost(X_train, y_train))
#print(J_sequence)

# %%
# Let's plot the cost as a function of number of iterations of the
# gradient descent algorithm.

plt.scatter(range(0, len(J_sequence)), J_sequence)
plt.show()

# %%
# Recreate original plot
print(W1, b1, W2, b2)

y_predicted = run_model(X_train)
plt.plot(x_data, y_numeric, -3, 3)
plt.plot(x_data, y_predicted)
plt.show()
