# %%
import numpy as np
import scipy 
import matplotlib.pyplot as plt
from scipy.special import softmax

sigmoid = scipy.special.expit

def identity(x): return x

def relu(x): return np.maximum(0, x)

# %%
# Build a 1-layer network, 3 -> 1, regression

x = np.array([.1, .2, .3])

# %%
# Build a 1-layer network, 3 -> 1, binary classification

# %%
# Build a 1-layer network, 3 -> 2, regression

# %%
# Build a 1-layer network, 3 -> 4, multi-class classification

# %%
# Build a 2-layer network, 3 -> 2 -> 1, regression

# %%
# Build a 2-layer network, 3 -> 2 -> 1, binary classification

# %%
# Build a 2-layer network, 3 -> 2 -> 4, multi-class binary classification
